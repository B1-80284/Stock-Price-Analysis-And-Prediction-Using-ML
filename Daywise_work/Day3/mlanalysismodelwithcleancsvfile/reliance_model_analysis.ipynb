# 33  Sep 14 2023  2453.30  2460.00  2465.80  2445.00   4.60M   0.09%
# 34  Sep 13 2023  2451.05  2440.00  2462.65  2426.25   6.40M   0.50%
# 35  Sep 12 2023  2438.85  2483.00  2483.00  2435.95   8.13M  -1.44%
# 36  Sep 11 2023  2474.60  2452.00  2476.85  2452.00   6.64M   1.08%
# 37  Sep 08 2023  2448.20  2440.00  2456.00  2422.95  11.55M   0.67%
# 38  Sep 07 2023  2432.00  2421.70  2438.25  2411.00   6.83M   0.14%
# 39  Sep 06 2023  2428.70  2421.10  2436.15  2417.25   4.10M   0.21%
# 40  Sep 05 2023  2423.60  2420.00  2433.95  2412.45   4.34M   0.54%
# 41  Sep 04 2023  2410.70  2412.65  2423.65  2405.30   4.67M  -0.08%
# 42  Sep 01 2023  2412.65  2406.55  2425.65  2401.65   9.06M   0.23%
# 43  Aug 31 2023  2407.00  2423.00  2425.00  2399.90  10.82M  -0.46%
# 44  Aug 30 2023  2418.05  2432.00  2443.00  2415.00   6.08M  -0.10%
# 45  Aug 29 2023  2420.35  2452.05  2453.45  2408.15   8.44M  -0.96%
# 46  Aug 28 2023  2443.75  2472.00  2484.00  2431.10   6.29M  -1.00%
# 47  Aug 25 2023  2468.35  2456.00  2505.00  2442.60  11.11M  -0.46%
# 48  Aug 24 2023  2479.80  2539.90  2539.90  2471.00   7.07M  -1.68%
# 49  Aug 23 2023  2522.20  2524.20  2542.85  2516.95   4.76M   0.11%

# %%
df.isna().sum()
# Out:
# Date       3
#  Open      0
#  High      0
#  Low       0
#  Close     0
#  Adj       0
#  Volume    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date       3
#  Open      0
#  High      0
#  Low       0
#  Close     0
#  Adj       0
#  Volume    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8151 entries, 0 to 8150
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     8148 non-null   object
#  1    Open    8151 non-null   float64
#  2    High    8151 non-null   float64
#  3    Low     8151 non-null   float64
#  4    Close   8151 non-null   float64
#  5    Adj     8151 non-null   object
#  6    Volume  8151 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 445.9+ KB

# %%
# Convert the 'Date' column to the desired format
df['Date'] = pd.to_datetime(df['Date'], format='%b %d %Y').dt.strftime('%Y-%m-%d')

# Print the DataFrame
print(df)
# Out:
#             Date     Open     High      Low    Close    Adj  Volume
# 0     2023-11-03  2319.70  2327.20  2334.95  2315.75  4.43M  -0.02%
# 1     2023-11-02  2320.20  2313.95  2324.30  2307.95  5.28M   0.99%
# 2     2023-11-01  2297.40  2289.15  2317.50  2275.20  5.15M   0.42%
# 3     2023-10-31  2287.90  2328.00  2328.00  2282.90  6.40M  -1.06%
# 4     2023-10-30  2312.50  2274.00  2325.00  2269.95  8.41M   2.06%
# ...          ...      ...      ...      ...      ...    ...     ...
# 8146  1990-01-08     6.71     7.05     7.05     6.67      0   0.00%
# 8147  1990-01-05     6.71     6.37     6.71     6.37      0   3.23%
# 8148  1990-01-04     6.50     6.24     6.58     6.24      0  -6.07%
# 8149  1990-01-03     6.92     7.18     7.18     6.84      0  -4.81%
# 8150  1990-01-02     7.27     7.31     7.44     7.14      0  -1.62%
#
# [8151 rows x 7 columns]

# %%
# Convert the 'Date' column to datetime if it's not already
df['Date'] = pd.to_datetime(df['Date'])

# Calculate the total number of days
total_days = (df['Date'].max() - df['Date'].min()).days

print(f"Total number of days: {total_days} days")
# Out:
# Total number of days: 12358 days

# %%
df.columns
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close', ' Adj', ' Volume'], dtype='object')

# %%
df.drop([' Adj',' Volume'], axis = 1, inplace= True)

# %% [markdown]
# ### 3. To do Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8151 entries, 0 to 8150
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8148 non-null   datetime64[ns]
#  1    Open   8151 non-null   float64
#  2    High   8151 non-null   float64
#  3    Low    8151 non-null   float64
#  4    Close  8151 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 318.5 KB

# %%
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           8148  8151.000000  8151.000000  8151.000000
# mean   2007-06-04 00:33:55.935198976   476.989906   477.463937   483.041477
# min              1990-01-02 00:00:00     4.360000     4.320000     4.400000
# 25%              1999-05-09 06:00:00    33.860000    33.785000    34.245000
# 50%              2007-06-20 12:00:00   303.870000   304.420000   309.120000
# 75%              2015-09-03 06:00:00   482.630000   483.390000   489.690000
# max              2023-11-03 00:00:00  2619.850000  2609.000000  2630.950000
# std                              NaN   642.481374   643.030536   649.486394
#
#              Close
# count  8151.000000
# mean    471.416075
# min       4.270000
# 25%      33.340000
# 50%     297.340000
# 75%     476.760000
# max    2580.000000
# std     636.038288

# %%
df.corr()
# Out:
#             Date      Open      High       Low     Close
# Date    1.000000  0.651679  0.651804  0.652088  0.651429
#  Open   0.651679  1.000000  0.999807  0.999922  0.999916
#  High   0.651804  0.999807  1.000000  0.999907  0.999900
#  Low    0.652088  0.999922  0.999907  1.000000  0.999871
#  Close  0.651429  0.999916  0.999900  0.999871  1.000000

# %%
df[[' Open', ' High', ' Low', ' Close']].plot(kind='box')
# Out:
# <Axes: >

# %%
# Setting the layout for our plot
layout = go.Layout(
    title='Stock Prices of Reliance',
    xaxis=dict(
        title='Date',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Price',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

reliance_data = [{'x':df['Date'], 'y':df[' Close']}]
plot = go.Figure(data=reliance_data, layout=layout)
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
#plot(plot) #plotting offline
iplot(plot)

# %% [markdown]
# ## 4. Data Pre- Processing

# %%
# Building the regression model
from sklearn.model_selection import train_test_split

#For preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#For model evaluation
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# %% [markdown]
# ### Split the data into train and test sets

# %%
X = np.array(df.index).reshape(-1,1)
Y = df[' Close']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %% [markdown]
# ### Feature scaling

# %%
scaler = StandardScaler().fit(X_train)

# %% [markdown]
# ### 5. Model Building

# %%
from sklearn.linear_model import LinearRegression

#Creating a linear model
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Plot actual and predicted values for train dataset
trace0 = go.Scatter(
    x = X_train.T[0],
    y = Y_train,
    mode = 'markers',
    name = 'Actual'
)
trace1 = go.Scatter(
    x = X_train.T[0],
    y = lm.predict(X_train).T,
    mode = 'lines',
    name = 'Predicted'
)
reliance_data = [trace0,trace1]
layout.xaxis.title.text = 'Day'
plot2 = go.Figure(data=reliance_data, layout=layout)

# %%
iplot(plot2)

# %% [markdown]
# ## 6.Model Evaluation

# %%
#Calculate scores for model evaluation
scores = f'''
{'Metric'.ljust(10)}{'Train'.center(20)}{'Test'.center(20)}
{'r2_score'.ljust(10)}{r2_score(Y_train, lm.predict(X_train))}\t{r2_score(Y_test, lm.predict(X_test))}
{'MSE'.ljust(10)}{mse(Y_train, lm.predict(X_train))}\t{mse(Y_test, lm.predict(X_test))}
'''
print(scores)
# Out:
# Metric           Train                Test
# r2_score  0.6451444144688754	0.6441434365801308
# MSE       141818.88243370331	147904.83811830854
